# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\leowe\anaconda3\lib\site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (3.20.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\leowe\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leowe\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\leowe\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\leowe\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leowe\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leowe\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\leowe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leowe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leowe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\leowe\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\leowe\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats

# %%
tickers = ['AAPL','SPY','BRK-B','GLD','TSLA']
data = yf.download(tickers, period='2y')['Close']
data=pd.DataFrame(data)
data=data.ffill()
print(data)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  5 of 5 completed
# Ticker            AAPL       BRK-B         GLD         SPY        TSLA
# Date
# 2023-11-01  172.282486  343.750000  183.509995  412.011780  205.660004
# 2023-11-02  175.847595  349.019989  184.119995  419.907776  218.509995
# 2023-11-03  174.936493  351.809998  184.789993  423.738708  219.960007
# 2023-11-06  177.491470  346.630005  183.350006  424.713501  219.270004
# 2023-11-07  180.056366  346.170013  182.589996  425.922241  222.179993
# ...                ...         ...         ...         ...         ...
# 2025-10-27  268.809998  488.070007  367.010010  685.239990  452.420013
# 2025-10-28  269.000000  481.440002  364.380005  687.059998  460.549988
# 2025-10-29  269.700012  475.760010  363.000000  687.390015  461.510010
# 2025-10-30  271.399994  478.519989  370.130005  679.830017  440.100006
# 2025-10-31  270.369995  477.540009  368.119995  682.059998  456.559998
#
# [502 rows x 5 columns]

# %%
log_returns = np.log(data/data.shift(1))
print(log_returns)
# Out:
# Ticker          AAPL     BRK-B       GLD       SPY      TSLA
# Date
# 2023-11-01       NaN       NaN       NaN       NaN       NaN
# 2023-11-02  0.020482  0.015215  0.003319  0.018983  0.060607
# 2023-11-03 -0.005195  0.007962  0.003632  0.009082  0.006614
# 2023-11-06  0.014500 -0.014833 -0.007823  0.002298 -0.003142
# 2023-11-07  0.014347 -0.001328 -0.004154  0.002842  0.013184
# ...              ...       ...       ...       ...       ...
# 2025-10-27  0.022535 -0.008223 -0.028234  0.011729  0.042212
# 2025-10-28  0.000707 -0.013677 -0.007192  0.002652  0.017810
# 2025-10-29  0.002599 -0.011868 -0.003794  0.000480  0.002082
# 2025-10-30  0.006283  0.005784  0.019451 -0.011059 -0.047502
# 2025-10-31 -0.003802 -0.002050 -0.005445  0.003275  0.036718
#
# [502 rows x 5 columns]

# %%
log_returns.corr()
# Out:
# Ticker      AAPL     BRK-B       GLD       SPY      TSLA
# Ticker
# AAPL    1.000000  0.350277  0.044936  0.689483  0.445528
# BRK-B   0.350277  1.000000  0.009791  0.513799  0.254096
# GLD     0.044936  0.009791  1.000000  0.088015  0.018713
# SPY     0.689483  0.513799  0.088015  1.000000  0.585180
# TSLA    0.445528  0.254096  0.018713  0.585180  1.000000
